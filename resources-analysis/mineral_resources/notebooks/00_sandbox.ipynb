# %% [markdown]
# # SANDBOX

# %%
# Imports
import json
import os
import logging
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import pycountry

from dash import Dash, html, Input, Output, dash_table
from jupyter_dash import JupyterDash
from pandas.api.types import is_string_dtype

#JupyterDash.infer_jupyter_proxy_config()

# %%
# Helpers
df = pd.read_csv("./aggregated_exports/exports_cobalt.csv")

countries = {}
for country in pycountry.countries:
    countries[country.name] = country.alpha_3

unabbreviated_countries = [country.strip() for country in df.Country.unique() if country not in countries.keys()]

# %%
unabbreviated_countries
# Out:
# ['Belgium-Luxembourg', 'German Federal Republic', 'USA', 'Zaire', 'Korea (Rep. of)', 'Soviet Union', 'Congo, Democratic Republic', 'Ireland, Republic of', 'Russia', 'Taiwan', 'Czech Republic']

# %%
countries["Belgium-Luxembourg"] = countries["Belgium"]
countries["Congo, Democratic Republic"] = countries["Congo, The Democratic Republic of the"]
countries["Czech Republic"] = countries["Czechia"]
countries["German Federal Republic"] = countries["Germany"]
countries["Ireland, Republic of"] = countries["Ireland"]
countries["Korea (Rep. of)"] = countries["Korea, Republic of"]
countries["Russia"] = countries["Russian Federation"]
countries["Soviet Union"] = countries["Russian Federation"]
countries["Taiwan"] = countries["Taiwan, Province of China"]
countries["USA"] = countries["United States"]
countries["Vietnam"] = countries["Viet Nam"]
countries["Zaire"] = countries["Congo, Democratic Republic"]

# %%
# Process data
df["Country code"] = df["Country"].apply(lambda x: countries.get(x, "Unknown code"))
df = df[df.columns].apply(lambda c: c.str.strip() if is_string_dtype(c) else c)
column_order = ["Country code", "Country", "Activity", "Commodity", "Sub-commodity", "Year", "Amount", "Measure"]
df = df[column_order]
df = df.dropna(subset=["Amount"], axis=0).reset_index(drop=True)
activity = df["Activity"].unique()[0]
commodity = df["Commodity"].unique()[0]

# %%
import plotly.graph_objects as go
import pandas as pd

from pprint import pprint

url = "https://raw.githubusercontent.com/plotly/datasets/master/gapminderDataFiveYear.csv"
dataset = pd.read_csv(url)

years = ["1952", "1962", "1967", "1972", "1977", "1982", "1987", "1992", "1997", "2002",
         "2007"]

# make list of continents
continents = []
for continent in dataset["continent"]:
    if continent not in continents:
        continents.append(continent)
# make figure
fig_dict = {
    "data": [],
    "layout": {},
    "frames": []
}

# fill in most of layout
fig_dict["layout"]["xaxis"] = {"range": [30, 85], "title": "Life Expectancy"}
fig_dict["layout"]["yaxis"] = {"title": "GDP per Capita", "type": "log"}
fig_dict["layout"]["hovermode"] = "closest"
fig_dict["layout"]["updatemenus"] = [
    {
        "buttons": [
            {
                "args": [None, {"frame": {"duration": 500, "redraw": False},
                                "fromcurrent": True, "transition": {"duration": 300,
                                                                    "easing": "quadratic-in-out"}}],
                "label": "Play",
                "method": "animate"
            },
            {
                "args": [[None], {"frame": {"duration": 0, "redraw": False},
                                  "mode": "immediate",
                                  "transition": {"duration": 0}}],
                "label": "Pause",
                "method": "animate"
            }
        ],
        "direction": "left",
        "pad": {"r": 10, "t": 87},
        "showactive": False,
        "type": "buttons",
        "x": 0.1,
        "xanchor": "right",
        "y": 0,
        "yanchor": "top"
    }
]

sliders_dict = {
    "active": 0,
    "yanchor": "top",
    "xanchor": "left",
    "currentvalue": {
        "font": {"size": 20},
        "prefix": "Year:",
        "visible": True,
        "xanchor": "right"
    },
    "transition": {"duration": 300, "easing": "cubic-in-out"},
    "pad": {"b": 10, "t": 50},
    "len": 0.9,
    "x": 0.1,
    "y": 0,
    "steps": []
}

# make data
year = 1952
for continent in continents:
    dataset_by_year = dataset[dataset["year"] == year]
    dataset_by_year_and_cont = dataset_by_year[
        dataset_by_year["continent"] == continent]

    data_dict = {
        "x": list(dataset_by_year_and_cont["lifeExp"]),
        "y": list(dataset_by_year_and_cont["gdpPercap"]),
        "mode": "markers",
        "text": list(dataset_by_year_and_cont["country"]),
        "marker": {
            "sizemode": "area",
            "sizeref": 200000,
            "size": list(dataset_by_year_and_cont["pop"])
        },
        "name": continent
    }
    fig_dict["data"].append(data_dict)

# make frames
for year in years:
    frame = {"data": [], "name": str(year)}
    for continent in continents:
        dataset_by_year = dataset[dataset["year"] == int(year)]
        dataset_by_year_and_cont = dataset_by_year[
            dataset_by_year["continent"] == continent]

        data_dict = {
            "x": list(dataset_by_year_and_cont["lifeExp"]),
            "y": list(dataset_by_year_and_cont["gdpPercap"]),
            "mode": "markers",
            "text": list(dataset_by_year_and_cont["country"]),
            "marker": {
                "sizemode": "area",
                "sizeref": 200000,
                "size": list(dataset_by_year_and_cont["pop"])
            },
            "name": continent
        }
        frame["data"].append(data_dict)

    fig_dict["frames"].append(frame)
    slider_step = {"args": [
        [year],
        {"frame": {"duration": 300, "redraw": False},
         "mode": "immediate",
         "transition": {"duration": 300}}
    ],
        "label": year,
        "method": "animate"}
    sliders_dict["steps"].append(slider_step)


fig_dict["layout"]["sliders"] = [sliders_dict]

fig = go.Figure(fig_dict)

fig.show()

# %% [markdown]
# ___

# %%
from pprint import pprint

# %%
#from plotly.tools import make_subplots
years = list(sorted(df["Year"].unique()))

# Make list of continents
df_countries = []
for country in df["Country code"]:
    if country not in df_countries:
        df_countries.append(country)

fig = go.Figure()
fig["layout"]["updatemenus"] = [
    {
        "buttons": [
            {
                "args": [None, {"frame": {"duration": 500, "redraw": False},
                                "fromcurrent": True, "transition": {"duration": 300,
                                                                    "easing": "quadratic-in-out"}}],
                "label": "Play",
                "method": "animate"
            },
            {
                "args": [[None], {"frame": {"duration": 0, "redraw": False},
                                  "mode": "immediate",
                                  "transition": {"duration": 0}}],
                "label": "Pause",
                "method": "animate"
            }
        ],
        "direction": "left",
        "pad": {"r": 10, "t": 87},
        "showactive": False,
        "type": "buttons",
        "x": 0.1,
        "xanchor": "right",
        "y": 0,
        "yanchor": "top"
    }
]

sliders_dict = {
    "active": 0,
    "yanchor": "top",
    "xanchor": "left",
    "currentvalue": {
        "font": {"size": 20},
        "prefix": "Year:",
        "visible": True,
        "xanchor": "right"
    },
    "transition": {"duration": 300, "easing": "cubic-in-out"},
    "pad": {"b": 10, "t": 50},
    "len": 0.9,
    "x": 0.1,
    "y": 0,
    "steps": []
}

pprint(fig)

for year in years:
    df_year = df[df["Year"] == year]
    fig.add_trace(go.Choropleth(arg=dict(locations=df_year["Country code"].values,
                                         z=df_year["Amount"].values,
                                         colorscale='blugrn',
                                         
                                    ),
                                visible='legendonly')
                 )
    slider_step = {"args": [
        [year],
        {"frame": {"duration": 300, "redraw": False},
         "mode": "immediate",
         "transition": {"duration": 300}}
    ],
        "label": str(year),
        "method": "animate"}
    sliders_dict["steps"].append(slider_step)
                            
#fig.add_scatter(y=[3, 1, 1.5], row=1, col=1, visible='legendonly')
#fig.add_scatter(y=[2, 2, 1], row=1, col=1, visible='legendonly')
#fig.add_scatter(y=[1, 3, 2], row=1, col=2, visible=True)
#fig.add_scatter(y=[1.5, 2, 2.5], row=1, col=2, visible='legendonly')
#fig.add_scatter(y=[2.5, 1.2, 2.9], row=1, col=2, visible='legendonly')

steps = []
for i in range(len(years)):
    step = dict(
        method = 'restyle',  
        args = ['visible', ['legendonly'] * len(fig.data)],
    )
    step['args'][1][i] = True
    steps.append(step)

sliders = [dict(
    steps = steps,
)]

#fig["layout"]["sliders"] = [sliders_dict]

fig.layout.sliders = sliders

fig.show()
# Out:
# Figure({
#     'data': [],
#     'layout': {'template': '...',
#                'updatemenus': [{'buttons': [{'args': [None, {'frame': {'duration':
#                                                       500, 'redraw': False},
#                                                       'fromcurrent': True,
#                                                       'transition': {'duration':
#                                                       300, 'easing': 'quadratic-in-
#                                                       out'}}],
#                                              'label': 'Play',
#                                              'method': 'animate'},
#                                             {'args': [[None], {'frame':
#                                                       {'duration': 0, 'redraw':
#                                                       False}, 'mode': 'immediate',
#                                                       'transition': {'duration':
# ...

# %%
fig["layout"]["updatemenus"]
# Out:
# ()

# %% [markdown]
# ___

# %%
years = list(sorted(df["Year"].unique()))
years = years[:2]

# Make list of continents
df_countries = []
for country in df["Country code"]:
    if country not in df_countries:
        df_countries.append(country)
# Make figure
fig_dict = {
    "data": [],
    "layout": {},
    "frames": []
}

# Fill in most of layout
fig_dict["layout"]["hovermode"] = "closest"
fig_dict["layout"]["updatemenus"] = [
    {
        "buttons": [
            {
                "args": [None, {"frame": {"duration": 500, "redraw": False},
                                "fromcurrent": True, "transition": {"duration": 300,
                                                                    "easing": "quadratic-in-out"}}],
                "label": "Play",
                "method": "animate"
            },
            {
                "args": [[None], {"frame": {"duration": 0, "redraw": False},
                                  "mode": "immediate",
                                  "transition": {"duration": 0}}],
                "label": "Pause",
                "method": "animate"
            }
        ],
        "direction": "left",
        "pad": {"r": 10, "t": 87},
        "showactive": False,
        "type": "buttons",
        "x": 0.1,
        "xanchor": "right",
        "y": 0,
        "yanchor": "top"
    }
]

sliders_dict = {
    "active": 0,
    "yanchor": "top",
    "xanchor": "left",
    "currentvalue": {
        "font": {"size": 20},
        "prefix": "Year:",
        "visible": True,
        "xanchor": "right"
    },
    "transition": {"duration": 300, "easing": "cubic-in-out"},
    "pad": {"b": 10, "t": 50},
    "len": 0.9,
    "x": 0.1,
    "y": 0,
    "steps": []
}

# Make data
year = 1970
for country in df_countries:
    dataset_by_year = df[df["Year"] == year]
    dataset_by_year_and_cont = dataset_by_year[
        dataset_by_year["Country code"] == country]

    data_dict = {
        "type": "choropleth",
        "locations": list(dataset_by_year_and_cont["Country code"].unique()),
        "z": [dataset_by_year_and_cont["Amount"].sum()],
        "colorscale": "blugrn", "hoverinfo": "location + z"
    }
    fig_dict["data"].append(data_dict)

# Make frames
for year in years:
    frame = {"data": [], "name": str(year)}
    for country in df_countries:
        dataset_by_year = df[df["Year"] == year]
        dataset_by_year_and_cont = dataset_by_year[
            dataset_by_year["Country code"] == country]

        data_dict = {
          "type": "choropleth",
          "locations": list(dataset_by_year_and_cont["Country code"].unique()),
          "z": [dataset_by_year_and_cont["Amount"].sum()],
          "colorscale": "blugrn", "hoverinfo": "location + z",
        }
        frame["data"].append(data_dict)

    fig_dict["frames"].append(frame)
    slider_step = {"args": [
        [year],
        {"frame": {"duration": 300, "redraw": False},
         "mode": "immediate",
         "transition": {"duration": 300}}
    ],
        "label": str(year),
        "method": "animate"}
    sliders_dict["steps"].append(slider_step)


fig_dict["layout"]["sliders"] = [sliders_dict]
#pprint(fig_dict["frames"])
fig = go.Figure(fig_dict["frames"], type="choropleth")

fig.update_layout(
    height=600,
    autosize= True,
    margin={
     "l": 10,
     "r": 10,
     "b": 10,
     "t": 30,
    })

fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [22], in <cell line: 110>()
#     108 fig_dict["layout"]["sliders"] = [sliders_dict]
#     109 #pprint(fig_dict["frames"])
# --> 110 fig = go.Figure(fig_dict["frames"], type="choropleth")
#     112 fig.update_layout(
#     113     height=600,
#     114     autosize= True,
#    (...)
#     119      "t": 30,
#     120     })
#     122 fig.show()
#
# File /usr/local/lib/python3.8/site-packages/plotly/graph_objs/_figure.py:594, in Figure.__init__(self, data, layout, frames, skip_invalid, **kwargs)
#       5 def __init__(
#       6     self, data=None, layout=None, frames=None, skip_invalid=False, **kwargs
#       7 ):
#       8     """
#       9     Create a new :class:Figure instance
#      10
#    (...)
#     592         is invalid AND skip_invalid is False
#     593     """
# ...

# %%
pprint(repr(fig))
# Out:
# ('Figure({\n'
#  "    'data': [{'colorscale': [[0.0, 'rgb(196, 230, 195)'], "
#  '[0.16666666666666666,\n'
#  "                             'rgb(150, 210, 164)'], [0.3333333333333333, "
#  "'rgb(109,\n"
#  "                             188, 144)'], [0.5, 'rgb(77, 162, 132)'],\n"
#  "                             [0.6666666666666666, 'rgb(54, 135, 122)'],\n"
#  "                             [0.8333333333333334, 'rgb(38, 107, 110)'], "
#  '[1.0,\n'
#  "                             'rgb(29, 79, 96)']],\n"
#  "              'hoverinfo': 'location+z',\n"
#  "              'locations': [BEL],\n"
#  "              'type': 'choropleth',\n"
#  "              'z': [1322.0]},\n"
#  "             {'colorscale': [[0.0, 'rgb(196, 230, 195)'], "
#  '[0.16666666666666666,\n'
#  "                             'rgb(150, 210, 164)'], [0.3333333333333333, "
#  "'rgb(109,\n"
#  "                             188, 144)'], [0.5, 'rgb(77, 162, 132)'],\n"
# ...

# %%
[dataset_by_year_and_cont["Amount"].sum()]
# Out:
# 'Belgium-Luxembourg'

# %% [markdown]
# ___

# %%
fig = go.Figure(data=go.Choropleth(locations=df["Country code"], z=df["Amount"],
                                   colorscale="blugrn",
                                   # animation_frame=df["Year"], 
                                  )
               )

title = f"Global yearly {activity} of {commodity} from {df.loc[:, 'Year'].min()} to {df.loc[:, 'Year'].max()}"
custom_layout = {"autosize": True,
                 "title_text": title,
                 #width=1000,
                 #height=500,
                 "margin": {
                   "l": 0,
                   "r": 0,
                   "b": 0,
                   "t": 30,
                 },
                }

fig.update_layout(custom_layout)
fig.show()

# %%
df_to_bar = df.groupby(["Country code"]).sum().sort_values(['Amount'], ascending=[False]).drop(columns=["Year"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [161], in <cell line: 1>()
# ----> 1 df_to_bar = df.groupby(["country_code"]).sum().sort_values(['Amount'], ascending=[False]).drop(columns=["Year"])
#
# File /usr/local/lib/python3.8/site-packages/pandas/core/frame.py:7712, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7707 axis = self._get_axis_number(axis)
#    7709 # https://github.com/python/mypy/issues/7642
#    7710 # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7711 # "Union[bool, NoDefault]"; expected "bool"
# -> 7712 return DataFrameGroupBy(
#    7713     obj=self,
#    7714     keys=by,
#    7715     axis=axis,
#    7716     level=level,
#    7717     as_index=as_index,
#    7718     sort=sort,
#    7719     group_keys=group_keys,
# ...

# %%
fig = px.bar(df_to_bar, x="Amount", y=df_to_bar.index.get_level_values(1), orientation='h',
             color_continuous_scale="blugrn", animation_frame=df_to_bar.index.get_level_values(0),
             width=900, height=500)

fig.update_layout(margin={"r":10, "t":0,"l":10,"b":0})
fig.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [63], in <cell line: 1>()
# ----> 1 fig = px.bar(df_to_bar, x="Amount", y=df_to_bar.index.get_level_values(1), orientation='h',
#       2              color_continuous_scale="blugrn", animation_frame=df_to_bar.index.get_level_values(0),
#       3              width=900, height=500)
#       5 fig.update_layout(margin={"r":10, "t":0,"l":10,"b":0})
#       6 fig.show()
#
# File /usr/local/lib/python3.8/site-packages/pandas/core/indexes/base.py:2008, in Index._get_level_values(self, level)
#    1972 def _get_level_values(self, level) -> Index:
#    1973     """
#    1974     Return an Index of values for requested level.
#    1975
#    (...)
#    2006     Index(['a', 'b', 'c'], dtype='object')
#    2007     """
# -> 2008     self._validate_index_level(level)
#    2009     return self
#
# ...
